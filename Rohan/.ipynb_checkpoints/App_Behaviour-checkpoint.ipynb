# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import datetime

# %%
df = pd.read_csv('../Data/appData_Analysis.csv')
df
# Out:
#          user               first_open  dayofweek       hour  age  \
# 0      235136  2012-12-27 02:14:51.273          3   02:00:00   23
# 1      333588  2012-12-02 01:16:00.905          6   01:00:00   24
# 2      254414  2013-03-19 19:19:09.157          1   19:00:00   23
# 3      234192  2013-07-05 16:08:46.354          4   16:00:00   28
# 4       51549  2013-02-26 18:50:48.661          1   18:00:00   31
# ...       ...                      ...        ...        ...  ...
# 49995  222774  2013-05-09 13:46:17.871          3   13:00:00   32
# 49996  169179  2013-04-09 00:05:17.823          1   00:00:00   35
# 49997  302367  2013-02-20 22:41:51.165          2   22:00:00   39
# 49998  324905  2013-04-28 12:33:04.288          6   12:00:00   27
# 49999   27047  2012-12-14 01:22:44.638          4   01:00:00   25
#
#                                              screen_list  numscreens  \
# 0      idscreen,joinscreen,Cycle,product_review,ScanP...          15
# ...

# %%
df['enrolled_date'].isna().sum()
# Out:
# 18926

# %%
print(pd.Timestamp(df['first_open'].values[0]).timestamp())
print(datetime.datetime.strptime(df['first_open'].values[0], '%Y-%m-%d %H:%M:%S.%f'))
# print(datetime.datetime.now().timestamp())
# Out:
# 2012-12-27 02:14:51.273000
# 2012-12-27 02:14:51.273000

# %%
df.isna().sum()
# Out:
# user                        0
# first_open                  0
# dayofweek                   0
# hour                        0
# age                         0
# screen_list                 0
# numscreens                  0
# minigame                    0
# used_premium_feature        0
# enrolled                    0
# enrolled_date           18926
# liked                       0
# dtype: int64

# %%
fig, ax =plt.subplots(1, 3, figsize=(20, 8))
sns.countplot(x = 'enrolled', hue = 'liked', data = df, ax = ax[0])
sns.countplot(x = 'enrolled', hue = 'used_premium_feature', data = df, ax = ax[1])
sns.countplot(x = 'enrolled', hue = 'minigame', data = df, ax = ax[2])

# %%
range_age  = df['age'].apply(lambda x : int(x / 10))
# ndf = pd.concat([range_age, df['screen_list']], axis = 1)

enrolled = df[df['enrolled'] == 1]
non_enrolled =  df[df['enrolled'] == 0]
enr_range_age  = enrolled['age'].apply(lambda x : int(x / 10))
nenr_range_age  = non_enrolled['age'].apply(lambda x : int(x / 10))
print(enr_range_age.value_counts())
print(nenr_range_age.value_counts())
# Out:
# 2     14805
# 3      8495
# 4      3413
# 1      2476
# 5      1338
# 6       431
# 7        92
# 8        19
# 9         4
# 10        1
# Name: age, dtype: int64
# 2     7105
# 3     5486
# 4     3103
# 5     1460
# 1     1256
# 6      436
# 7       63
# 8       15
# 10       2
# Name: age, dtype: int64

# %%
tmp_first_open = df['first_open'].apply(lambda x : float(x.split(':')[0])*24*7 + float(x.split(':')[1]))
tmp_access_time = pd.Series(df['dayofweek']*24 + (df['hour'].apply(lambda x : float(x[:2]))), name = 'access_time')
tmp_first_open = tmp_first_open.to_frame()
tmp_access_time = tmp_access_time.to_frame()

ndf = df.drop(labels = ['screen_list', 'user', 'enrolled_date', 'first_open', 'dayofweek', 'hour'], axis = 1, inplace = False)

ndf = pd.concat([tmp_first_open, tmp_access_time,ndf], axis = 1)
enrolled_data = ndf.loc[ndf['enrolled'] == 1]
non_enrolled_data = ndf.loc[ndf['enrolled'] == 0]

fig, ax = plt.subplots(4, 2, figsize=(10, 13))
sns.distplot(a = enrolled_data['access_time'], norm_hist=False, ax = ax[0, 0])
sns.distplot(a = non_enrolled_data['access_time'], norm_hist=False, ax = ax[0, 1])
sns.distplot(a = enrolled_data['first_open'], norm_hist=False, ax = ax[1, 0])
sns.distplot(a = non_enrolled_data['first_open'], norm_hist=False, ax = ax[1, 1])
sns.distplot(a = enrolled_data['age'], norm_hist=False, ax = ax[2, 0])
sns.distplot(a = non_enrolled_data['age'], norm_hist=False, ax = ax[2, 1])
sns.distplot(a = enrolled_data['numscreens'], norm_hist=False, ax = ax[3, 0])
sns.distplot(a = non_enrolled_data['numscreens'], norm_hist=False, ax = ax[3, 1])

# %%
from sklearn.model_selection import train_test_split

labels = df['enrolled']
features = df.drop(['enrolled_date','enrolled'], axis = 1)

screen_vocab = set([x for x in (','.join(df['screen_list'])).split(',')])
screen_index = {s:i for i,s in enumerate(screen_vocab)}
vocab_size = len(screen_vocab)

df_screen_indices = list(df['screen_list'].apply(lambda x : [screen_index[w] for w in x.split(',')]))

X_tot, X_Test, Y_tot, Y_Test = train_test_split(features, labels, test_size=0.1, random_state=20)
X_Train, X_validate, Y_Train, Y_validate = train_test_split(X_tot, Y_tot, test_size=0.11, random_state=20) 
#train = 40000, validate = 5000, test = 5000
print('Shape of X_Train: ', X_Train.shape)
print('Shape of X_validate: ', X_validate.shape)
print('Shape of X_Test: ', X_Test.shape)
print('Vocab_Size: ',  vocab_size)
# Out:
# Shape of X_Train:  (40050, 10)
# Shape of X_validate:  (4950, 10)
# Shape of X_Test:  (5000, 10)
# Vocab_Size:  137

# %%
# # print(screen_index.keys())
# one_hot_vec = np.identity(vocab_size)
# screen_encoded = df['screen_list'].apply(lambda x: np.sum([one_hot_vec[screen_index[w]] for w in list(set(x.split(',')))], axis = 0))
# # print([ w for w in screen_index.keys()])
# # print(np.stack(screen_encoded.values, axis = 0))
# screen_df = pd.DataFrame(np.stack(screen_encoded.values, axis = 0), columns = [ w for w in screen_index.keys()])
# # print(screen_encoded)

# doc_freq = np.sum(screen_encoded.values, axis = 0).astype('int')
# rev_dict = {v:k for k,v in screen_index.items()}
# df_dict = {rev_dict[i]:doc_freq[i] for i in range(vocab_size)}
# ndf = pd.concat([screen_df, df], axis = 1)
# # print(sorted(df_dict.items()))
# entr_dict = {}
# for v in range(vocab_size):
#     probs = ndf.groupby(rev_dict[v]).mean()[['enrolled']]['enrolled']
#     entr = 0
#     for i in [0, 1]:
#         if probs[i] == 0 or probs[i] == 1:
#             entropy = 0
#         else:
#             entropy = -probs[i]*np.log(probs[i]) - (1 - probs[i])*np.log(1 - probs[i])
#         entr += entropy
#     entr_dict[rev_dict[v]] = entr

# entropy_sorted = {k:v for k, v in sorted(entr_dict.items(), key = lambda item: item[1], reverse = True)}
# df_sorted = {k:v for k, v in sorted(df_dict.items(), key = lambda item: item[1], reverse = True)}

# mylist = zip(list(entropy_sorted), list(df_sorted))
# for x,y in mylist:
#     print(x, " ", y)

# %%
# corr_mat = screen_df.corr()

# %%
# corr_others = np.abs(np.array(corr_mat) - np.identity(vocab_size))
# thresh = 0.5
# max_corr = np.where(corr_others > 0.5, axis = 1)
# max_corr_dict = {rev_dict[i]:rev_dict[x] for i, x in enumerate(max_corr)}
# for k, v in max_corr_dict.items():
#     print(k, " : ", v)

# %%
# enrolled_screens = df[df['enrolled'] == 1][['screen_list']]
# non_enrolled_screens = df[df['enrolled'] == 0][['screen_list']]
# enrolled_indices = np.concatenate([[screen_index[w] for w in x.split(',')] for x in enrolled_screens['screen_list']], axis = 0)
# non_enrolled_indices = np.concatenate([[screen_index[w] for w in x.split(',')] for x in non_enrolled_screens['screen_list']], axis = 0)

# enr_vals, enr_counts = np.unique(enrolled_indices, return_counts= True)
# non_enr_vals, non_enr_counts = np.unique(non_enrolled_indices, return_counts= True)

# enr_freqs = np.zeros(vocab_size)
# non_enr_freqs = np.zeros(vocab_size)

# enr_freqs[enr_vals] = enr_counts
# non_enr_freqs[non_enr_vals] = non_enr_counts

# plt.bar(range(vocab_size), enr_freqs)
# plt.show()
# plt.figure()
# plt.bar(range(vocab_size), non_enr_freqs)
# plt.show()
# plt.figure()
# weights = np.zeros((2, vocab_size))
# weights[0, :] = (non_enr_freqs - enr_freqs)/(enr_freqs + non_enr_freqs)
# weights[1, :] = (enr_freqs - non_enr_freqs)/(enr_freqs + non_enr_freqs)
# plt.bar(range(vocab_size), (enr_freqs - non_enr_freqs)/(enr_freqs + non_enr_freqs))
# plt.show()

# %%
# df.corr()

# %%
#HyperParameters
n_trees = 100
pca_dim = 1500
train_bsize = 5000
max_dist = 1000

# %%
word_vectors = np.identity(vocab_size)
idf = np.zeros(vocab_size)
for i in range(X_Train.shape[0]):
    idf[list(set(df_screen_indices[i]))] += 1
idf_arr = np.log((1.0 + X_Train.shape[0]*np.ones(vocab_size))/(1.0 + idf))

# %%
train_indices = X_Train['screen_list'].apply(lambda x: [screen_index[w] for w in x.split(',')])
tr_w, tr_c = np.unique(np.concatenate(train_indices.values), return_counts=True)
tr_freqs = np.zeros((vocab_size, 2), dtype = 'int')
tr_freqs[tr_w, 1] = tr_c
tr_freqs[tr_w, 0] = tr_w
sorted_ind = np.argsort(tr_freqs[:, 1], axis = 0)
sorted_freq = tr_freqs[sorted_ind, :]
red_vocab_size = 137
red_freqs = sorted_freq[:red_vocab_size, :]
red_vocab = red_freqs[:, 0]
train_indices = None

# %%
# max_val = 1000
# dist_sentence = None
# dist_sentence = 1000*np.ones((X_Train.shape[0], int(red_vocab_size*(red_vocab_size-1)/2)), dtype = 'int')

# %%
# for i in range(X_Train.shape[0]):
#     sentence = [x for x in train_indices.values[i] if x in red_vocab]
#     sen_len = len(sentence)
#     if(sen_len > 1):
#         all_pairs = np.array([[(red_vocab_size + min(sentence[m], sentence[n]) - max(sentence[m], sentence[n]))*(red_vocab_size + min(sentence[m], sentence[n]) - max(sentence[m], sentence[n]) - 1)/2 + min(sentence[m], sentence[n]) , n-m] for m in range(sen_len-1) for n in range(m+1, sen_len)], dtype = 'int')
#         dist_sentence[i, all_pairs[:, 0]] = all_pairs[:, 1]

# %%
# # dist_df = pd.DataFrame(dist_sentence, columns = ['c' + str(i) for i in range(int(red_vocab_size*(red_vocab_size+1)/2))], index = train_indices.index)
# ndim = 5000
# tpca = PCA(n_components=ndim)
# _ = tpca.fit_transform(dist_sentence[:5000, :])
# eigsum = [np.sum(tpca.explained_variance_[:k]) for k in range(ndim)]
# plt.plot(range(ndim), eigsum)
# plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

pca = PCA(n_components = pca_dim)
scaler = StandardScaler()

# %%
def pre_process_scale(X, label):  
    screen_indices = list(X['screen_list'].apply(lambda x : [screen_index[w] for w in x.split(',')]))
    dist_vec = max_dist*np.ones((X.shape[0], int(red_vocab_size*(red_vocab_size+1)/2)), dtype = 'int')
    
    for i in range(X.shape[0]):
        sentence = [x for x in screen_indices[i] if x in red_vocab]
        sen_len = len(sentence)
        if(sen_len > 1):
            all_pairs = np.array([[(red_vocab_size + min(sentence[m], sentence[n]) - max(sentence[m], sentence[n]))*(red_vocab_size + min(sentence[m], sentence[n]) - max(sentence[m], sentence[n]) - 1)/2 + min(sentence[m], sentence[n]) , n-m] for m in range(sen_len-1) for n in range(m+1, sen_len)], dtype = 'int')
            dist_vec[i, all_pairs[:, 0]] = all_pairs[:, 1]
            
    if(label == 'pca_train'):   
        pca.fit_transform(dist_vec[:train_bsize, :])
        return
    
    else:
        princ_comp = pd.DataFrame(pca.transform(dist_vec), columns = ['D' + str(i) for i in range(pca_dim)], index = X.index)
        dist_vec = None
        sentence_vec = np.zeros((X.shape[0], vocab_size))
        for i in range(X.shape[0]):
            x = tuple(screen_indices[i])
            sentence_vec[i, : ]= np.sum(word_vectors[x, :], axis = 0)
        screen_df = pd.DataFrame(sentence_vec, columns = ['P' + str(i) for i in range(vocab_size)], index = X.index)
        first_open = X['first_open'].apply(lambda x : float(x.split(':')[0])*60.0 + float(x.split(':')[1])*60.0)
        access_time = pd.Series(X['dayofweek']*24 + (X['hour'].apply(lambda x : float(x[:2]))), name = 'access_time')
        first_open = first_open.to_frame()
        access_time = access_time.to_frame()

        XN = X.drop(labels = ['screen_list', 'user', 'first_open', 'dayofweek', 'hour'], axis = 1)

        XFinal = pd.concat([first_open, access_time, princ_comp, screen_df, XN], axis = 1)
        if(label == 'train'):
            return(scaler.fit_transform(XFinal))
        else:
            return(scaler.transform(XFinal))

# %%
# pre_process_scale(X_Train, 'show_var', 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

def fit_model(Train_D, Validation_D, Test_D, Train_L, Validation_L, Test_L):
    validation_acc = []
    train_acc = []
    models = []
    for depth in range(10, 100, 9):
        model = RandomForestClassifier(n_estimators = n_trees, max_depth = depth)
        model.fit(Train_D, Train_L)
        Y_Test_pred = model.predict(Validation_D)
        Y_Train_pred = model.predict(Train_D)
        validation_acc.append(accuracy_score(Validation_L, Y_Test_pred))
        train_acc.append(accuracy_score(Train_L, Y_Train_pred))
        models.append(model)
    plt.plot(range(10, 100, 9), validation_acc)
    plt.plot(range(10, 100, 9), train_acc)
    plt.show()
    print(max(validation_acc))
    model = models[np.argmax(validation_acc)]
    return model

# %%
proc_data = {}
for data, label in [(X_Train, 'pca_train'), (X_Train, 'train'), (X_validate, 'validate'), (X_Test, 'test')]:
    proc_data[label] = pre_process_scale(data, label)
Train_Data = proc_data['train']
Validation_Data = proc_data['validate']
Test_Data = proc_data['test']
# Out:
# /home/rohanganesh/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.843030303030303

# %%
mymodel = RandomForestClassifier(n_estimators = 100, max_depth = 200)
mymodel.fit(Train_Data, Y_Train)
valid_preds = mymodel.predict(Validation_Data)
print(accuracy_score(Y_validate, valid_preds))
# Out:
# 0.8145454545454546

# %%
# import xgboost as xgb
# param = {
#     'eta': 0.3, 
#     'max_depth': 8,  
#     'objective': 'multi:softprob',  
#     'num_class': 2} 

# steps = 15

# for epochs in range(1):
#     proc_data = {}
#     for data, label in [(X_Train, 'train'), (X_validate, 'validate'), (X_Test, 'test')]:
#         proc_data[label] = pre_process_scale(data, label, 0)
#     Train_Data = proc_data['train']
#     Validation_Data = proc_data['validate']
#     Test_Data = proc_data['test']
#     D_train = xgb.DMatrix(Train_Data, label=Y_Train)
#     D_test = xgb.DMatrix(Validation_Data, label=Y_validate)
#     model = xgb.train(param, D_train, steps)
#     preds = model.predict(D_test)
#     best_preds = np.asarray([np.argmax(line) for line in preds])

#     print("Accuracy = {}".format(accuracy_score(Y_validate, best_preds)))

# %%
# from sklearn import svm
# mymodels = []
# for epochs in range(1):
#     proc_data = {}
#     for data, label in [(X_Train, 'train'), (X_validate, 'validate'), (X_Test, 'test')]:
#         proc_data[label] = pre_process_scale(data, label, 0)
#     Train_Data = proc_data['train']
#     Validation_Data = proc_data['validate']
#     Test_Data = proc_data['test']
#     model = svm.SVC(gamma = 0.1, C = 0.1)
#     model.fit(Train_Data, Y_Train)
#     mymodels.append(model)

# %%
#  preds = model.predict(Validation_Data)
#  print("Accuracy = {}".format(accuracy_score(Y_validate, preds)))
